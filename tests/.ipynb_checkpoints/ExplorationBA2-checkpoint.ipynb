# %% [markdown]
# ## Installation
# Nous utilisons Plotly et Dash pour visualiser pour installer.
#
# ### Plotly installation :
# ```
# conda install -c plotly plotly=4.7.1
#
# #Pour Jupyter Notebook
#
# conda install "notebook>=5.3" "ipywidgets>=7.2"
#
# #Pour Jupyter
#
# conda install jupyterlab "ipywidgets=7.5"
#
# # JupyterLab renderer support
# jupyter labextension install jupyterlab-plotly@4.7.1
#
# # OPTIONAL: Jupyter widgets extension
# jupyter labextension install @jupyter-widgets/jupyterlab-manager plotlywidget@4.7.1
# ```
# ### Dash installation
# ```
# pip install dash==1.12.0
# ```

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import sys 
# sys.path.append('/users/loulou/cedia/simfin/Model')
import numpy as np
import warnings
import simfin
import pandas as pd
warnings.filterwarnings('ignore')

# %%
pwd
# Out:
# 'C:\\Users\\Bertrand\\Dropbox (CEDIA)\\simfin\\Model\\tests'

# %%
data = {inf/10 : pd.read_csv('../dashapp/data/output_'+str(inf/10)+'.csv') for inf in range(10,40,5) }
data[1.0]
# Out:
#     Unnamed: 0  Years       personal     corporate    consumption  \
# 0            0   2019   31773.000000   9183.000000   21001.000000
# 1            1   2020   35698.623008  10292.216997   23504.524707
# 2            2   2021   40051.380988  11508.957455   26268.428136
# 3            3   2022   44850.842180  12871.858315   29293.423083
# 4            4   2023   50085.490197  14370.400896   32604.524426
# 5            5   2024   56109.677297  16073.830953   36436.718206
# 6            6   2025   62885.748842  17992.620572   40741.006012
# 7            7   2026   70325.125274  20080.653821   45478.885963
# 8            8   2027   78558.465649  22438.221048   50740.598447
# 9            9   2028   87727.512515  25085.041483   56547.343000
# 10          10   2029   97920.492152  27998.386722   63117.135000
# 11          11   2030  109414.883476  31266.053093   70419.536532
# 12          12   2031  122025.076725  34934.397380   78301.946356
# 13          13   2032  136188.621627  39043.822134   87230.764925
# 14          14   2033  151943.427789  43627.088413   97152.757485
# 15          15   2034  169225.162926  48654.473353  107904.028094
# 16          16   2035  188498.457831  54292.421283  119939.661301
# 17          17   2036  210284.159980  60631.272260  133419.975084
# 18          18   2037  234080.283096  67611.257449  148162.857957
# 19          19   2038  260911.187281  75470.239800  164865.111693
# 20          20   2039  289892.176387  83988.227352  182954.696182
#
#       other taxes     autonomous  federal transfers  total revenue  \
# 0    29669.000000   91626.000000       23120.000000   1.147460e+05
# 1    33252.726350  102748.091062       25912.670910   1.286608e+05
# 2    37183.846101  115012.612681       28976.053182   1.439887e+05
# 3    41587.189846  128603.313425       32407.422874   1.610107e+05
# 4    46428.773187  143489.188706       36180.297148   1.796695e+05
# 5    51932.319562  160552.546017       40469.015749   2.010216e+05
# 6    58131.662827  179751.038254       45299.944203   2.250510e+05
# 7    64877.808801  200762.473859       50556.976625   2.513195e+05
# 8    72494.781692  224232.066837       56492.613594   2.807247e+05
# 9    81046.291598  250406.188596       63156.502132   3.135627e+05
# 10   90458.906202  279494.920075       70491.419036   3.499863e+05
# 11  101016.283264  312116.756365       78718.408746   3.908352e+05
# 12  112868.195128  348129.615589       87954.183537   4.360838e+05
# 13  126145.176836  388608.385523       98300.464743   4.869089e+05
# 14  140953.074825  433676.348511      109839.734738   5.435161e+05
# 15  157195.858641  482979.523014      122497.160396   6.054767e+05
# 16  175411.286840  538141.827256      136691.797895   6.748336e+05
# 17  195891.235618  600226.642942      152651.096009   7.528777e+05
# 18  218442.600158  668296.998659      170224.574999   8.385216e+05
# 19  243833.882677  745080.421451      190011.101402   9.350915e+05
# 20  271354.319647  828189.419568      211456.802394   1.039646e+06
#
#     mission health  ...  fund contribution   net surplus        reserve  \
# 0     41522.000000  ...        3477.000000   4803.000000            NaN
# 1     47111.163833  ...        2673.197515   7756.724629   14930.724629
# 2     53286.828305  ...        2870.321544   9408.881072   19756.419487
# 3     60086.460221  ...        3152.123775  11699.356564   21923.888394
# 4     66996.432192  ...        3451.902516  14745.135561   24220.867167
# 5     76776.596048  ...        3747.357975  16762.126707   27076.811563
# 6     87900.643116  ...        4036.321754  19065.964289   30292.304462
# 7     99868.953859  ...           0.000000  27695.412453   33543.605705
# 8    113714.494723  ...           0.000000  30375.893063   37552.318105
# 9    128331.886570  ...           0.000000  34063.591024   41924.864956
# 10   146272.885374  ...           0.000000  35979.559269   47101.016976
# 11   166797.762267  ...           0.000000  38468.749245   52854.962380
# 12   187811.011839  ...           0.000000  42505.791756   59036.701106
# 13   213405.648041  ...           0.000000  44941.831033   66295.052885
# 14   241976.512105  ...           0.000000  47165.211634   74452.630742
# 15   273602.828014  ...           0.000000  48678.058212   83519.793780
# 16   307484.267867  ...           0.000000  52818.102481   93302.328401
# 17   348712.987493  ...           0.000000  55094.862635  104667.431447
# 18   393980.690844  ...           0.000000  55951.526241  117385.507113
# 19   448825.131626  ...           0.000000  53278.621658  132271.935179
# 20   504185.406596  ...           0.000000  52035.130915  148141.663657
#
#              debt     gross debt           gdp  debt-to-gdp  gdp growth  \
# 0   195188.000000  199098.000000  4.587330e+05     0.434017    0.022654
# 1   203337.659137  201525.465217  5.141435e+05     0.391963    0.020790
# 2   200307.298611  197241.671289  5.749253e+05     0.343074    0.018219
# 3   192512.123625  188105.488634  6.430084e+05     0.292540    0.018421
# 4   182002.867709  176135.696325  7.178675e+05     0.245360    0.016420
# 5   170265.418552  162914.523842  8.029616e+05     0.202892    0.018537
# 6   124095.344525  148005.172342  8.988140e+05     0.164667    0.019374
# 7   102360.579942  129045.129499  1.003121e+06     0.128644    0.016049
# 8    79020.836488  108838.283014  1.120892e+06     0.097100    0.017405
# 9    52714.347079   86049.070068  1.253113e+06     0.068668    0.017960
# 10   25688.572537   62894.748424  1.398648e+06     0.044968    0.016139
# 11   -2807.714504   38740.760493  1.561883e+06     0.024804    0.016709
# 12  -34418.305881   12004.916511  1.745133e+06     0.006879    0.017327
# 13  -66833.866631  -14949.758877  1.950418e+06    -0.007665    0.017633
# 14  -99955.192823  -41980.526603  2.179373e+06    -0.019263    0.017388
# 15 -133001.469411  -68346.069397  2.430514e+06    -0.028120    0.015235
# 16 -168711.728551  -96564.236782  2.712156e+06    -0.035604    0.015877
# 17 -204260.921186 -123689.929638  3.028810e+06    -0.040838    0.016754
# 18 -238372.042678 -148525.568252  3.377493e+06    -0.043975    0.015122
# 19 -266581.547920 -166291.518923  3.770085e+06    -0.044108    0.016238
# 20 -291414.987634 -179805.672771  4.195597e+06    -0.042856    0.012866
#
#     pop growth  emp growth
# 0          NaN         NaN
# 1    -0.001616    0.012135
# 2     0.005969    0.009564
# 3     0.004767    0.009765
# 4     0.002971    0.007764
# 5     0.007188    0.009882
# 6     0.007175    0.010718
# 7     0.005124    0.007394
# 8     0.006056    0.008749
# 9     0.004506    0.009305
# 10    0.006173    0.007483
# 11    0.005828    0.008053
# 12    0.003206    0.008671
# 13    0.005301    0.008977
# 14    0.005201    0.008732
# 15    0.002964    0.006580
# 16    0.002862    0.007222
# 17    0.003863    0.008098
# 18    0.002352    0.006466
# 19    0.004625    0.007582
# 20    0.002637    0.004210
#
# [21 rows x 27 columns]

# %%
# %%time
# for i in range (10,40,5):
#     print(i/10)
#     x = simfin.simulator(2019,2040)
#     x.macro.infl = i/100
#     x.simulate()
#     output = x.summary.T
#     output.index.name = "Years"
#     output = output.reset_index()
#     output.to_csv('output_'+str(i/10)+'.csv')

x = simfin.simulator(2019,2040)
x.simulate()
output = x.summary.T
output.index.name = "Years"
output = output.reset_index()
output.to_csv('output_'+str(i/10)+'.csv')
# Out:
# non_work/earnings : 0.23513785892786498
# alignment factor for consommation :  1.7363158353334043
# alignment factor for consommation tax :  0.6673311873873553
# alignment factor for personal tax :  0.5718312805386435
# alignment factor for health :  1.2387687285036388
# alignment factor for education :  1.3237548874284988

# %%
pwd()
# Out:
# 'C:\\Users\\Bertrand\\Dropbox (CEDIA)\\simfin\\Model\\tests'

# %%
#output.keys()

# %% [markdown]
# ## On prépare les graphiques

# %%
#mode='lines'
total = make_subplots(specs=[[{"secondary_y": True}]])
total.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'total revenue'],
                    mode='lines+markers',
                    name='Revenu total'),secondary_y=False)
total.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'total revenue']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio revenu total'),secondary_y=True)

total.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'total spending'],
                    mode='lines+markers',
                    name='Dépense total'),secondary_y=False)
total.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'total spending']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratop dépenses total'),secondary_y=True)
total.update_layout(
    title_text="Revenus et dépenses totales"
)
total.update_yaxes(title_text="Totals en M$", secondary_y=False)
total.update_yaxes(title_text="Totals en % du PIB", secondary_y=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ecde364a6d2e> in <module>
#       1 #mode='lines'
#       2 total = make_subplots(specs=[[{"secondary_y": True}]])
# ----> 3 total.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'total revenue'],
#       4                     mode='lines+markers',
#       5                     name='Revenu total'),secondary_y=False)
#
# NameError: name 'output' is not defined

# %%
#mode='lines'
total2 = make_subplots(specs=[[{"secondary_y": True}]])
total2.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'total revenue'],
                    mode='lines+markers',
                    name='Revenu total'),secondary_y=False)

total2.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'total spending'],
                    mode='lines+markers',
                    name='Dépense total'),secondary_y=False)

total2.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'net surplus'],
                    mode='lines+markers',
                    name='Surplus net'),secondary_y=True)
total2.update_layout(
    title_text="Revenus et dépenses totales"
)
total2.update_yaxes(title_text="Totals en M$", secondary_y=False)
total2.update_yaxes(title_text="Totals en % du PIB", secondary_y=True)

# %%
surplus = make_subplots(specs=[[{"secondary_y": True}]])
surplus.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'surplus'],
                    mode='lines+markers',
                    name='Surplus'),secondary_y=False)
surplus.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'surplus']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio Surplus'),secondary_y=True)
surplus.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'net surplus'],
                    mode='lines+markers',
                    name='Surplus net'),secondary_y=False)
surplus.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'net surplus']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio Surplus net'),secondary_y=True)

surplus.update_layout(
    title_text="Surplus et surplus net")

surplus.update_yaxes(title_text="Surplus en M$", secondary_y=False)
surplus.update_yaxes(title_text="Surplus en % du PIB", secondary_y=True)

# %%
missions = make_subplots(specs=[[{"secondary_y": True}]])
missions.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'mission health'],
                    mode='lines+markers',
                    name='Mission Santé'),secondary_y=False)
missions.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'mission health']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio mission santé'),secondary_y=True)
missions.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'mission education'],
                    mode='lines+markers',
                    name='Mission éducation'),secondary_y=False)
missions.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'mission education']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio mission éducation'),secondary_y=True)

missions.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'other missions'],
                    mode='lines+markers',
                    name='Autres missions'),secondary_y=False)
missions.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'other missions']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio autres missions'),secondary_y=True)

missions.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'debt service']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio paiment debt'),secondary_y=True)

missions.update_layout(
    title_text="Missions")

missions.update_yaxes(title_text="Missions en M$", secondary_y=False)
missions.update_yaxes(title_text="Missions en % du PIB", secondary_y=True)

# %%
(26.9/23.8)

# %%
(92.8/41.5)**(1/20)-1 #avec tcam <0

# %%
(97.23/41.5)**(1/20)-1 #sans tcam <0

# %%
(38.3/23.8)**(1/20)-1

# %%
taxes = make_subplots(specs=[[{"secondary_y": True}]])

taxes.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'personal'],
                    mode='lines+markers',
                    name='Taxe revenu individu'),secondary_y=False)
taxes.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'personal']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio Taxe revenu individu'),secondary_y=True)

taxes.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'corporate'],
                    mode='lines+markers',
                    name='Taxe entreprise'),secondary_y=False)
taxes.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'corporate']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio taxe entreprise'),secondary_y=True)


taxes.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'consumption'],
                    mode='lines+markers',
                    name='Taxe à la consommation'),secondary_y=False)
taxes.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'consumption']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio taxe à la consommation'),secondary_y=True)

taxes.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'other taxes'],
                    mode='lines+markers',
                    name='Autres taxes'),secondary_y=False)
taxes.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'other taxes']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio autres taxes'),secondary_y=True)

taxes.update_layout(
    title_text="Taxes")

taxes.update_yaxes(title_text="Taxes en M$", secondary_y=False)
taxes.update_yaxes(title_text="Taxes en % du PIB", secondary_y=True)

# %%
other_revenu = make_subplots(specs=[[{"secondary_y": True}]])

other_revenu.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'autonomous'],
                    mode='lines+markers',
                    name='Revenu autonomes '),secondary_y=False)
other_revenu.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'autonomous']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio revenu autonomes'),secondary_y=True)

other_revenu.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'federal transfers'],
                    mode='lines+markers',
                    name='Transfères fédéraux'),secondary_y=False)
other_revenu.add_trace(go.Scatter(x=output["Years"], y=output.loc[:,'federal transfers']/output.loc[:,'gdp']*100,
                    mode='lines+markers',
                    name='Ratio transfères fédéraux'),secondary_y=True)

other_revenu.update_layout(
    title_text="Autres revenus")

other_revenu.update_yaxes(title_text="Autres revenu en M$", secondary_y=False)
other_revenu.update_yaxes(title_text="Autres revenu en % du PIB", secondary_y=True)

# %% [markdown]
# ## On construit le Dashboard et on start le serveur.
# Pour accéder au dashboard juste aller dans un autre onglet à http://127.0.0.1:8051/ après avoir démarrer le serveur (rouler la prochaine cellule.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
app = dash.Dash()
app.layout = html.Div(
    children = [
    dcc.Graph(figure=total),
    dcc.Graph(figure=surplus),
    dcc.Graph(figure=missions),
    dcc.Graph(figure=taxes),
    dcc.Graph(figure=other_revenu),
])

app.run_server(port='8051',debug=True, use_reloader=False)  # Turn off reloader if inside Jupyter

# %%
1/0.676563*0.005856
