# %% [markdown]
# # Exemple avec SimFin

# %%
import numpy as np
from matplotlib import pyplot as plt
from importlib import reload 
import sys 
sys.path.append('/users/loulou/cedia/simfin/Model')
import warnings
import simfin
import pandas as pd
import os
import plotly.graph_objects as go
from plotly.subplots import make_subplots
warnings.filterwarnings('ignore')
module_dir = '../'
simfin = reload(simfin)

# %%
family_credits = pd.DataFrame(pd.read_pickle(module_dir+'/simfin/params/credit_famille.pkl'))
family_credits
# Out:
#                                     credit_famille
# age educ insch male  nkids married
# 18  dec  False False 0     False      1.148353e-16
#                            True       2.361296e-17
#                      1     False      1.576669e-01
#                            True       5.894932e-02
#                      2     False      2.403928e-01
# ...                                            ...
# 110 uni  False True  5     True       8.343630e-03
#                      6     False     -9.217126e-17
#                            True       8.343630e-03
#                      7     False     -9.217126e-17
#                            True       8.343630e-03
#
# [14208 rows x 1 columns]

# %%
tcam = pd.read_pickle(module_dir+'simfin/params/health_cihi_growth.pkl')
tcam =tcam.groupby('age').mean()
tcam
# Out:
#         Drugs  Hospitals  Other Institutions  Other Professionals  Physicians  \
# age
# 0    0.021460   0.024138            0.265883             0.148728    0.058322
# 1   -0.013000   0.022821            0.287440             0.075051    0.044722
# 2   -0.013000   0.017598            0.273946             0.075757    0.046072
# 3   -0.013000   0.012375            0.260453             0.076462    0.047421
# 4   -0.008623   0.007152            0.246959             0.077167    0.048771
# ..        ...        ...                 ...                  ...         ...
# 105 -0.013000   0.008629            0.015819            -0.013000    0.042875
# 106 -0.013000   0.008629            0.015819            -0.013000    0.042875
# 107 -0.013000   0.008629            0.015819            -0.013000    0.042875
# 108 -0.013000   0.008629            0.015819            -0.013000    0.042875
# 109 -0.013000   0.008629            0.015819            -0.013000    0.042875
#
#         Total
# age
# 0    0.028508
# 1    0.035673
# 2    0.035866
# 3    0.036059
# 4    0.036252
# ..        ...
# 105  0.014440
# 106  0.014440
# 107  0.014440
# 108  0.014440
# 109  0.014440
#
# [110 rows x 6 columns]

# %%
#mode='lines'
tcam_fig = make_subplots()
tcam_fig.add_trace(go.Scatter(x=tcam["age"], y=tcam.loc[:,'drugs'],
                    mode='lines+markers',
                    name='Médicament'))
tcam_fig.update_layout(
    title_text="Taux de croissance par catégorie -> converge vers Total en 2025"
)
tcam_fig.update_yaxes(title_text="taux de croissance")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-020953662a62> in <module>
#       1 #mode='lines'
# ----> 2 tcam_fig = make_subplots()
#       3 tcam_fig.add_trace(go.Scatter(x=tcam["age"], y=tcam.loc[:,'drugs'],
#       4                     mode='lines+markers',
#       5                     name='Médicament'))
#
# NameError: name 'make_subplots' is not defined

# %%
x = simfin.simulator(2019,2041)
# Out:
# non_work/earnings : 0.23453392421818633
# alignment factor for consommation :  1.7354308028832097
# alignment factor for consommation tax :  0.6674868014370197
# alignment factor for personal tax :  0.5724825037590938
# alignment factor for health :  1.2477680010889918
# alignment factor for education :  1.3109346302077027

# %%
pop_2017 = x.pop[2017]
pop_2017.loc[0:4]
# Out:
# age  male   insch  educ  married  nkids  chsld
# 0    False  False  none  False    0      False    41136.960108
#      True   False  none  False    0      False    43243.726267
# 1    False  False  dec   False    0      False        0.000000
#                                          True         0.000000
#                                   1      False        0.000000
#                                                       ...
# 4    True   True   uni   True     3      True         0.000000
#                                   4      False        0.000000
#                                          True         0.000000
#                                   5      False        0.000000
#                                          True         0.000000
# Name: 2017, Length: 1538, dtype: float64

# %%
# %%time
x.simulate()
# Out:
# CPU times: user 12.4 s, sys: 602 ms, total: 13 s
# Wall time: 12.9 s

# %%
x.summary
# Out:
#                         2019        2020         2021         2022  \
# personal               31773     32577.9      33416.5      34229.7
# corporate               9183     9394.71      9606.05      9817.19
# consumption            21001     21506.4      22032.3      22546.9
# other taxes            29669       30353      31035.8        31718
# autonomous             91626     93831.9      96090.7      98311.7
# federal transfers      23120       23653      24185.1      24716.7
# total revenue         114746      117485       120276       123028
# mission health         41522     43355.1      45451.6      47498.9
# mission education      23887     24837.2      25805.2      26805.7
# other missions         32335     33080.5      33824.6      34568.1
# mission spending       97744      101273       105081       108873
# debt service            8722     8422.72      8475.58      8529.64
# total spending        106466      109695       113557       117402
# surplus                 8280     7789.48      6718.89      5626.09
# generation fund         8293     15489.2      18359.5      21511.6
# fund contribution       3477      2673.2      2870.32      3152.12
# net surplus             4803     5116.28      3848.57      2473.97
# reserve                  NaN     12290.3      16138.8      17610.4
# debt                  195188      203217       204513       204835
# gross debt            199098      200212       198918       196369
# gdp                   458733      469309       479866       490414
# debt-to-gdp         0.434017     0.42661     0.414529     0.400415
# gdp growth         0.0357579   0.0230541    0.0224963    0.0219799
# pop growth               NaN -0.00752773   0.00548707   0.00504033
# emp growth               NaN  0.00129425  0.000736459  0.000220072
#
#                           2023         2024         2025         2026  \
# personal                 35063      35923.8      36790.1      37683.3
# corporate                10037      10262.9        10495      10726.2
# consumption            23093.8      23650.1      24218.8      24841.4
# other taxes            32428.1      33157.9      33907.9      34654.8
# autonomous              100622       102995       105412       107906
# federal transfers      25270.1      25838.7      26423.2      27005.2
# total revenue           125892       128833       131835       134911
# mission health         49673.4      52046.9        54601      57160.1
# mission education      27987.6      29231.7      30547.4      31823.7
# other missions           35342      36137.4      36954.8      37768.8
# mission spending        113003       117416       122103       126753
# debt service           8543.07       8588.2      8645.95      7339.21
# total spending          121546       126004       130749       134092
# surplus                 4345.8      2829.26       1085.9      819.001
# generation fund        24963.5      28710.9            0            0
# fund contribution       3451.9      3747.36      4036.32            0
# net surplus            893.899     -918.097     -2950.42      819.001
# reserve                18231.9      17313.8      14363.4      15182.4
# debt                    205917       207301       175970       177417
# gross debt              194291       192228       189917       191671
# gdp                     501394       512677       524274       535822
# debt-to-gdp           0.387502     0.374951     0.362247     0.357714
# gdp growth           0.0223889    0.0225032     0.022621     0.022026
# pop growth          0.00531282   0.00526194   0.00552039   0.00546682
# emp growth         0.000629001  0.000743364  0.000861112  0.000266168
#
#                          2027        2028  ...        2031        2032  \
# personal              38566.8     39437.8  ...     42212.9     43219.6
# corporate             10970.6     11224.4  ...     12058.8     12370.2
# consumption           25424.6       26004  ...     27801.5     28429.4
# other taxes           35444.5     36264.6  ...     38960.3     39966.3
# autonomous             110406      112931  ...      121033      123985
# federal transfers     27620.6     28259.7  ...     30360.4     31144.3
# total revenue          138027      141191  ...      151394      155130
# mission health        59605.2     62068.1  ...     69937.4     72901.3
# mission education     33173.3       34627  ...     38862.2     40389.8
# other missions        38629.5     39523.3  ...     42461.2     43557.6
# mission spending       131408      136218  ...      151261      156849
# debt service          7399.57     7461.31  ...     7655.37     7950.22
# total spending         138808      143680  ...      158916      164799
# surplus              -780.553    -2489.08  ...    -7522.35    -9669.05
# generation fund             0           0  ...           0           0
# fund contribution           0           0  ...           0           0
# net surplus          -780.553    -2489.08  ...    -7522.35    -9669.05
# reserve               14401.9     11912.8  ...           0           0
# debt                   178898      180412  ...      190620      201958
# gross debt             193476      195328  ...      206645      218396
# gdp                    548032      560712  ...      602393      617946
# debt-to-gdp          0.353038    0.348356  ...     0.34304    0.353423
# gdp growth          0.0227879   0.0231384  ...    0.024559   0.0258198
# pop growth         0.00451961  0.00423322  ...  0.00350387  0.00360551
# emp growth         0.00102808   0.0013785  ...  0.00279909  0.00405995
#
#                          2033       2034        2035        2036        2037  \
# personal              44204.9    45213.4     46242.3     47335.4       48459
# corporate             12684.2    13008.3     13337.7     13675.6     14032.7
# consumption           29054.8    29672.4     30312.9     30998.9     31682.6
# other taxes           40980.8      42028     43092.2     44183.9     45337.8
# autonomous             126925     129922      132985      136194      139512
# federal transfers     31934.9      32751     33580.2       34431     35330.1
# total revenue          158860     162673      166565      170625      174842
# mission health          75885    78892.4     81849.7     85082.1     88156.8
# mission education     42102.3      43782     45527.9     47311.2     49012.4
# other missions        44663.3    45804.6     46964.4     48154.2     49411.7
# mission spending       162651     168479      174342      180547      186581
# debt service           8423.1    9003.89     9694.77     10498.5     11427.2
# total spending         171074     177483      184037      191046      198008
# surplus              -12214.2   -14809.8    -17471.5    -20421.2    -23165.8
# generation fund             0          0           0           0           0
# fund contribution           0          0           0           0           0
# net surplus          -12214.2   -14809.8    -17471.5    -20421.2    -23165.8
# reserve                     0          0           0           0           0
# debt                   215884     232449      251720      273986      299045
# gross debt             232739     249735      269444      292159      317693
# gdp                    633633     649825      666279      683158      700999
# debt-to-gdp          0.367309   0.384311    0.404401     0.42766    0.453201
# gdp growth          0.0253845  0.0255543   0.0253206   0.0253341   0.0261145
# pop growth         0.00310201  0.0026186   0.0024349  0.00288751  0.00249769
# emp growth         0.00362467  0.0037944  0.00356072  0.00357422  0.00435466
#
#                          2038        2039        2040
# personal              49589.6     50689.1     51798.7
# corporate             14392.2     14748.3     15110.8
# consumption           32373.5     33053.9     33748.1
# other taxes           46499.3     47649.7     48821.1
# autonomous             142855      146141      149479
# federal transfers     36235.3     37131.7     38044.5
# total revenue          179090      183273      187523
# mission health        91288.1     94247.7       97495
# mission education     50768.3     52573.9     54518.5
# other missions        50677.7     51931.4       53208
# mission spending       192734      198753      205221
# debt service          12472.3     13642.6     14940.2
# total spending         205206      212395      220162
# surplus              -26116.4    -29122.8    -32638.5
# generation fund             0           0           0
# fund contribution           0           0           0
# net surplus          -26116.4    -29122.8    -32638.5
# reserve                     0           0           0
# debt                   327103      358216      392893
# gross debt             346229      377815      412974
# gdp                    718958      736745      754856
# debt-to-gdp           0.48157    0.512816    0.547089
# gdp growth          0.0256202   0.0247389   0.0245835
# pop growth         0.00215662  0.00181777  0.00200835
# emp growth         0.00386036  0.00297907  0.00282366
#
# [25 rows x 22 columns]

# %%
#x.summary['tcam10'] = (x.summary[2030]/x.summary[2020])**(1/10)-1.0

# %%
y = simfin.simulator(2019,2041)
# Out:
# non_work/earnings : 0.23416691157190983
# alignment factor for consommation :  1.7350016645647124
# alignment factor for consommation tax :  0.6672986534110941
# alignment factor for personal tax :  0.5717638707688916
# alignment factor for health :  1.2443114588152808
# alignment factor for education :  1.315197614762375

# %%
y.genfund.strategy.loc[:] = 0.0

# %%
y.simulate()

# %%
plt.figure()
plt.plot(x.summary.columns,x.summary.loc['debt-to-gdp',:],label='avec contribution')
plt.plot(y.summary.columns,y.summary.loc['debt-to-gdp',:],label='sans contribution')
plt.xlabel('annee')
plt.ylabel('ratio dette brutte PIB')
plt.title('Évolution du ratio dette-brutte PIB sans contribution au Fonds 2020-2025')
plt.legend()
plt.tight_layout()
plt.savefig('de')
plt.show()

# %%
pd.concat([x.summary.loc['surplus':,[2019,2020,2021]],y.summary.loc['surplus':,[2019,2020,2021]]],axis=1)
# Out:
#                         2019        2020         2021       2019        2020  \
# surplus                 8280     7789.48      6718.89       8280     7789.48
# generation fund         8293     15489.2      18359.5       8293     13315.2
# fund contribution       3477      2673.2      2870.32       3477     499.198
# net surplus             4803     5116.28      3848.57       4803     7290.28
# reserve                  NaN     12290.3      16138.8        NaN     14464.3
# debt                  195188      203217       204513     195188      203217
# gross debt            199098      200212       198918     199098      202386
# gdp                   458733      469309       479866     458733      469309
# debt-to-gdp         0.434017     0.42661     0.414529   0.434017    0.431242
# gdp growth         0.0357579   0.0230541    0.0224963  0.0357579   0.0230541
# pop growth               NaN -0.00752773   0.00548707        NaN -0.00752773
# emp growth               NaN  0.00129425  0.000736459        NaN  0.00129425
#
#                           2021
# surplus                6718.89
# generation fund        13833.8
# fund contribution      518.642
# net surplus            6200.25
# reserve                17033.5
# debt                    200882
# gross debt              199813
# gdp                     479866
# debt-to-gdp           0.416393
# gdp growth           0.0224963
# pop growth          0.00548707
# emp growth         0.000736459
