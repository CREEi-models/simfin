# %%
from simfin import simulator, replicator

# %%
x = simulator(2021,2050)

# %%
x.pop.head()
# Out:
#                                             2021          2022          2023  \
# age educ insch male  nkids married
# 0   none False False 0     False    41984.204404  42618.814547  41895.888040
#                True  0     False    42445.022105  42063.128223  42698.775683
# 1   dec  False False 0     False        0.000000      0.000000      0.000000
#                      1     False        0.000000      0.000000      0.000000
#                      2     False        0.000000      0.000000      0.000000
#
#                                             2024          2025          2026  \
# age educ insch male  nkids married
# 0   none False False 0     False    42241.573510  42085.851826  41736.056668
#                True  0     False    42314.776246  42408.712075  42471.210829
# 1   dec  False False 0     False        0.000000      0.000000      0.000000
#                      1     False        0.000000      0.000000      0.000000
# ...

# %%
mc = replicator(nreps=100,ncpus=8)

# %%
mc.set_model(x)
# Out:
# copied models...

# %%
mc.replicate()

# %%
mc.stats
# Out:
# [2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050]
