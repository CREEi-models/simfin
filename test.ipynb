# %%
from simfin import simulator, replicator

# %%
x = simulator(2021,2025)

# %%
x.simulate()

# %%
x.macro.aggr
# Out:
#                   Y             Yp               H               E  \
# 2021  474517.079439  476757.364108  1593883.975379  4104104.675086
# 2022   458648.37349  479956.336336  1468145.608713  4106224.116298
# 2023  479947.565006  510672.060661  1350415.569883  4109757.378132
# 2024  550229.861182  590031.014387  1460802.578318  4114226.581829
#
#                    N      infl     YperH     sp500      b1yr      b5yr  \
# 2021  8478492.841146  0.042424  0.297711 -0.054069  0.002796  0.011881
# 2022  8528265.486811  0.044909    0.3124 -0.134576  0.005616  0.017692
# 2023  8571435.357161  0.026775  0.355407  0.003156  0.004504  0.018378
# 2024  8620849.573095  0.034285  0.376663  0.071035 -0.003746  0.011397
#
#          b10yr     b30yr   gr_wage      gr_Y      gr_H     gr_Yp  gr_YperH  \
# 2021  0.021794  0.032505 -0.001201  0.073568  0.074769  0.078637 -0.043625
# 2022  0.028739  0.039105  0.045446 -0.033442 -0.078888   0.00671  0.000538
# ...

# %%
x.revenue.report
# Out:
#                                  2021          2022          2023  \
# personal_taxes           31481.533884  32574.416652  34925.672756
# personal_credits_other    1565.101664   1575.603267   1676.437014
# personal_credits_family   3810.939939   4086.447679   4290.114046
# corporate_taxes           7124.394547   7172.198193   7631.196744
# corporate_credits         2159.430414   2173.919876   2313.044039
# fss                       7034.867712   7082.070646   7535.301311
# property_taxes            1660.021682   1671.160185   1778.109279
# consumption              23226.908387  25188.349622  26702.516608
# permits                   4891.616847   4924.438881   5239.587772
# gov_enterprises           4766.495005   4798.477489   5105.565240
# miscellaneous_income      9513.574551   9577.409245  10190.333880
#
#                                  2024
# personal_taxes           39873.047574
# personal_credits_other    1936.957018
# personal_credits_family   4485.374475
# ...

# %%
x.missions.report
# Out:
#                        2021          2022          2023          2024
# health         38617.877545  39778.932979  43258.859345  52071.610266
# education      20096.783400  20270.972548  21714.536251  25631.460273
# economy        18652.862212  18778.020191  19979.755532  23084.629710
# family_credit   3810.939939   4086.447679   4290.114046   4485.374475
# family_kg       2853.114030   2982.544817   3069.648569   3182.697858
# family_other    5033.996874   5067.774257   5392.096170   6230.033358
# justice        10250.283328  10319.061231  10979.449304  12685.666809

# %%
x.pop.head()
# Out:
#                                             2020          2021          2022  \
# age educ insch male  nkids married
# 0   none False False 0     False    42647.910132  41984.204404  42618.814547
#                True  0     False    41382.982376  42445.022105  42063.128223
# 1   dec  False False 0     False        0.000000      0.000000      0.000000
#                      1     False        0.000000      0.000000      0.000000
#                      2     False        0.000000      0.000000      0.000000
#
#                                             2023          2024          2025  \
# age educ insch male  nkids married
# 0   none False False 0     False    41895.888040  42241.573510  42085.851826
#                True  0     False    42698.775683  42314.776246  42408.712075
# 1   dec  False False 0     False        0.000000      0.000000      0.000000
#                      1     False        0.000000      0.000000      0.000000
# ...

# %%
mc = replicator(nreps=100,ncpus=8)

# %%
mc.set_model(x)
# Out:
# copied models...

# %%
mc.replicate()

# %%
mc.stats
# Out:
# [2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050,
#  2050]
